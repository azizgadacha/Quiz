# %% [markdown]
# <a href="https://colab.research.google.com/github/azizgadacha/Quiz/blob/main/gprMax_colab_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# After restarting, ignore the warning it is normal
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !git clone https://github.com/gprMax/gprMax.git
# !ls
# Out:
# Cloning into 'gprMax'...
# remote: Enumerating objects: 16759, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 16759 (delta 0), reused 0 (delta 0), pack-reused 16755 (from 1)
# Receiving objects: 100% (16759/16759), 197.44 MiB | 19.88 MiB/s, done.
# Resolving deltas: 100% (11823/11823), done.
# condacolab_install.log	gprMax	sample_data

# %%
# !pip install pycuda
# Out:
# Collecting pycuda
#   Downloading pycuda-2024.1.2.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 17.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytools>=2011.2 (from pycuda)
#   Downloading pytools-2024.1.16-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/site-packages (from pycuda) (4.1.0)
# Collecting mako (from pycuda)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4 (from pytools>=2011.2->pycuda)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting MarkupSafe>=0.9.2 (from mako->pycuda)
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading pytools-2024.1.16-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.0/89.0 kB 7.9 MB/s eta 0:00:00
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.9 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Building wheels for collected packages: pycuda
#   Building wheel for pycuda (pyproject.toml) ... done
#   Created wheel for pycuda: filename=pycuda-2024.1.2-cp310-cp310-linux_x86_64.whl size=663849 sha256=33e43a64292288fc022506e9c851a1fb161f53d7b7255efe3a9c3921d3b78cbc
#   Stored in directory: /root/.cache/pip/wheels/70/63/40/4bf006182f942d3516b71bb2ff3b57ccbdb8b2c0ee81882b6e
# Successfully built pycuda
# Installing collected packages: typing-extensions, MarkupSafe, pytools, mako, pycuda
# Successfully installed MarkupSafe-3.0.2 mako-1.3.6 pycuda-2024.1.2 pytools-2024.1.16 typing-extensions-4.12.2

# %%
# !ls
# Out:
# condacolab_install.log	gprMax	sample_data

# %%
import os
os.chdir('gprMax/')
os.getcwd()
# Out:
# '/content/gprMax'

# %%
# % cd gprMax
# !mamba env update -n base -f conda_env.yml
# build
# !conda activate gprMax
# !python setup.py build
# !python setup.py install
# Out:
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   4%
# conda-forge/noarch     1%[+] 0.3s
# conda-forge/linux-64   9%
# conda-forge/noarch    12%[+] 0.4s
# conda-forge/linux-64  17%
# conda-forge/noarch    30%[+] 0.5s
# conda-forge/linux-64  21%
# conda-forge/noarch    49%[+] 0.6s
# conda-forge/linux-64  25%
# conda-forge/noarch    49%[+] 0.7s
# conda-forge/linux-64  29%
# conda-forge/noarch    58%[+] 0.8s
# conda-forge/linux-64  29%
# conda-forge/noarch    68%[+] 0.9s
# conda-forge/linux-64  33%
# conda-forge/noarch    77%[+] 1.0s
# conda-forge/linux-64  37%
# conda-forge/noarch    87%[+] 1.1s
# conda-forge/linux-64  41%
# conda-forge/noarch    96%conda-forge/noarch
# [+] 1.2s
# conda-forge/linux-64  46%[+] 1.3s
# conda-forge/linux-64  54%[+] 1.4s
# conda-forge/linux-64  62%[+] 1.5s
# conda-forge/linux-64  66%[+] 1.6s
# conda-forge/linux-64  70%[+] 1.7s
# conda-forge/linux-64  78%[+] 1.8s
# conda-forge/linux-64  87%[+] 1.9s
# conda-forge/linux-64  95%conda-forge/linux-64
#
#
# Looking for: ["python[version='>3.6']", 'colorama', 'cython', 'h5py', 'jupyter', 'matplotlib', 'numpy', 'pip', 'psutil', 'scipy']
#
#
#
#   Pinned packages:
#
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - cython
#    - h5py
#    - jupyter
#    - matplotlib
#    - numpy
#    - psutil
#    - scipy
#    - python[version='>3.6']
#    - colorama
#    - pip
#
#
#   Package                                 Version  Build                    Channel           Size
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + libgcc                                 14.2.0  h77fa898_1               conda-forge      849kB
#   + libglvnd                                1.7.0  ha4b6fd6_2               conda-forge      132kB
#   + libexpat                                2.6.4  h5888daf_0               conda-forge       73kB
#   + alsa-lib                               1.2.13  hb9d3cd8_0               conda-forge      560kB
#   + xorg-xorgproto                         2024.1  hb9d3cd8_1               conda-forge      565kB
#   + xorg-libice                             1.1.1  hb9d3cd8_1               conda-forge       58kB
#   + libdeflate                               1.22  hb9d3cd8_0               conda-forge       72kB
#   + xorg-libxdmcp                           1.1.5  hb9d3cd8_0               conda-forge       20kB
#   + pthread-stubs                             0.4  hb9d3cd8_1002            conda-forge        8kB
#   + xorg-libxau                            1.0.11  hb9d3cd8_1               conda-forge       15kB
#   + libgfortran5                           14.2.0  hd5240d6_1               conda-forge        1MB
#   + libstdcxx                              14.2.0  hc0a3c3a_1               conda-forge        4MB
#   + libopengl                               1.7.0  ha4b6fd6_2               conda-forge       51kB
#   + libegl                                  1.7.0  ha4b6fd6_2               conda-forge       45kB
#   + expat                                   2.6.4  h5888daf_0               conda-forge      138kB
#   + xorg-libsm                              1.2.4  he73a12e_1               conda-forge       28kB
#   + libxcb                                 1.17.0  h8a09558_0               conda-forge      396kB
#   + libgfortran                            14.2.0  h69a702a_1               conda-forge       54kB
#   + libsodium                              1.0.18  h36c2ea0_1               conda-forge      375kB
#   + wayland                                1.23.1  h3e06ad9_0               conda-forge      322kB
#   + libpciaccess                             0.18  hd590300_0               conda-forge       28kB
#   + libbrotlicommon                         1.1.0  hd590300_1               conda-forge       69kB
#   + pixman                                 0.43.2  h59595ed_0               conda-forge      387kB
#   + graphite2                              1.3.13  h59595ed_1003            conda-forge       97kB
#   + lerc                                    4.0.0  h27087fc_0               conda-forge      282kB
#   + libjpeg-turbo                           3.0.0  hd590300_1               conda-forge      619kB
#   + qhull                                  2020.2  h434a139_5               conda-forge      553kB
#   + libwebp-base                            1.4.0  hd590300_0               conda-forge      439kB
#   + double-conversion                       3.3.0  h59595ed_0               conda-forge       79kB
#   + yaml                                    0.2.5  h7f98852_2               conda-forge       89kB
#   + libaec                                  1.1.3  h59595ed_0               conda-forge       35kB
#   + libxcrypt                              4.4.36  hd590300_1               conda-forge      100kB
#   + xcb-util-wm                             0.4.2  hb711507_0               conda-forge       52kB
#   + xcb-util-renderutil                    0.3.10  hb711507_0               conda-forge       17kB
#   + xcb-util-keysyms                        0.4.1  hb711507_0               conda-forge       14kB
#   + xcb-util                                0.4.1  hb711507_2               conda-forge       20kB
#   + xorg-libx11                            1.8.10  h4f16b4b_0               conda-forge      838kB
#   + libgfortran-ng                         14.2.0  h69a702a_1               conda-forge       54kB
#   + libopenblas                            0.3.28  pthreads_h94d23a6_1      conda-forge        6MB
#   + zeromq                                  4.3.5  h75354e8_4               conda-forge      353kB
#   + libdrm                                2.4.123  hb9d3cd8_0               conda-forge      303kB
#   + libbrotlienc                            1.1.0  hd590300_1               conda-forge      283kB
#   + libbrotlidec                            1.1.0  hd590300_1               conda-forge       33kB
#   + libpng                                 1.6.44  hadc24fc_0               conda-forge      291kB
#   + zlib                                    1.3.1  hb9d3cd8_2               conda-forge       92kB
#   + pcre2                                   10.43  hcad00b1_0               conda-forge      951kB
#   + libcups                                 2.3.3  h4637d8d_4               conda-forge        5MB
#   + mysql-common                            8.3.0  h70512c7_5               conda-forge      780kB
#   + libpq                                    16.3  ha72fbe1_0               conda-forge        3MB
#   + xcb-util-image                          0.4.0  hb711507_2               conda-forge       25kB
#   + xorg-libxrender                        0.9.11  hb9d3cd8_1               conda-forge       38kB
#   + xorg-libxext                            1.3.6  hb9d3cd8_0               conda-forge       50kB
#   + xkeyboard-config                         2.43  hb9d3cd8_0               conda-forge      389kB
#   + libglx                                  1.7.0  ha4b6fd6_2               conda-forge       76kB
#   + libblas                                 3.9.0  25_linux64_openblas      conda-forge       16kB
#   + brotli-bin                              1.1.0  hd590300_1               conda-forge       19kB
#   + freetype                               2.12.1  h267a509_2               conda-forge      635kB
#   + libglib                                2.80.2  hf974151_0               conda-forge        4MB
#   + libxslt                                1.1.39  h76b75d6_0               conda-forge      254kB
#   + libllvm18                              18.1.8  h8b73ec9_2               conda-forge       38MB
#   + libtiff                                 4.7.0  he137b08_1               conda-forge      428kB
#   + libllvm19                              19.1.2  ha7bfdaf_0               conda-forge       40MB
#   + mysql-libs                              8.3.0  ha479ceb_5               conda-forge        2MB
#   + xcb-util-cursor                         0.1.5  hb9d3cd8_0               conda-forge       20kB
#   + libxkbcommon                            1.7.0  h2c5496b_1               conda-forge      593kB
#   + libgl                                   1.7.0  ha4b6fd6_2               conda-forge      135kB
#   + libcblas                                3.9.0  25_linux64_openblas      conda-forge       16kB
#   + liblapack                               3.9.0  25_linux64_openblas      conda-forge       16kB
#   + brotli                                  1.1.0  hd590300_1               conda-forge       19kB
#   + fontconfig                             2.15.0  h7e30c49_1               conda-forge      266kB
#   + dbus                                   1.13.6  h5008d03_3               conda-forge      619kB
#   + libclang-cpp18.1                       18.1.8  default_hf981a13_5       conda-forge       19MB
#   + openjpeg                                2.5.2  h488ebb8_0               conda-forge      342kB
#   + lcms2                                    2.16  hb7c19ff_0               conda-forge      245kB
#   + libclang13                             19.1.2  default_h9c6a7e4_1       conda-forge       12MB
#   + hdf5                                   1.14.3  nompi_hdf9ad27_105       conda-forge        4MB
#   + font-ttf-dejavu-sans-mono                2.37  hab24e00_0               conda-forge      397kB
#   + font-ttf-inconsolata                    3.000  h77eed37_0               conda-forge       97kB
#   + font-ttf-source-code-pro                2.038  h77eed37_0               conda-forge      701kB
#   + font-ttf-ubuntu                          0.83  h77eed37_3               conda-forge        2MB
#   + fonts-conda-forge                           1  0                        conda-forge        4kB
#   + ipython_genutils                        0.2.0  pyhd8ed1ab_1             conda-forge       28kB
#   + types-python-dateutil          2.9.0.20241003  pyhff2d567_0             conda-forge       22kB
#   + pytz                                   2024.2  pyhd8ed1ab_0             conda-forge      187kB
#   + parso                                   0.8.4  pyhd8ed1ab_0             conda-forge       75kB
#   + json5                                  0.9.28  pyhff2d567_0             conda-forge       29kB
#   + wcwidth                                0.2.13  pyhd8ed1ab_0             conda-forge       33kB
#   + pure_eval                               0.2.3  pyhd8ed1ab_0             conda-forge       17kB
#   + executing                               2.1.0  pyhd8ed1ab_0             conda-forge       28kB
#   + ptyprocess                              0.7.0  pyhd3deb0d_0             conda-forge       17kB
#   + munkres                                 1.1.4  pyh9f0ad1d_0             conda-forge       12kB
#   + pyparsing                               3.2.0  pyhd8ed1ab_1             conda-forge       92kB
#   + cycler                                 0.12.1  pyhd8ed1ab_0             conda-forge       13kB
#   + cached_property                         1.5.2  pyha770c72_1             conda-forge       11kB
#   + hyperframe                              6.0.1  pyhd8ed1ab_0             conda-forge       15kB
#   + six                                    1.16.0  pyh6c4a22f_0             conda-forge       14kB
#   + soupsieve                                 2.5  pyhd8ed1ab_1             conda-forge       37kB
#   + webencodings                            0.5.1  pyhd8ed1ab_2             conda-forge       16kB
#   + hpack                                   4.0.0  pyh9f0ad1d_0             conda-forge       25kB
#   + sniffio                                 1.3.1  pyhd8ed1ab_0             conda-forge       15kB
#   + zipp                                   3.21.0  pyhd8ed1ab_0             conda-forge       22kB
#   + typing_extensions                      4.12.2  pyha770c72_0             conda-forge       40kB
#   + exceptiongroup                          1.2.2  pyhd8ed1ab_0             conda-forge       20kB
#   + decorator                               5.1.1  pyhd8ed1ab_0             conda-forge       12kB
#   + attrs                                  24.2.0  pyh71513ae_0             conda-forge       56kB
#   + pkgutil-resolve-name                   1.3.10  pyhd8ed1ab_1             conda-forge       11kB
#   + webcolors                              24.8.0  pyhd8ed1ab_0             conda-forge       18kB
#   + uri-template                            1.3.0  pyhd8ed1ab_0             conda-forge       24kB
#   + pickleshare                             0.7.5  py_1003                  conda-forge        9kB
#   + python-json-logger                      2.0.7  pyhd8ed1ab_0             conda-forge       13kB
#   + websocket-client                        1.8.0  pyhd8ed1ab_0             conda-forge       47kB
#   + rfc3986-validator                       0.1.1  pyh9f0ad1d_0             conda-forge        8kB
#   + typing_utils                            0.1.0  pyhd8ed1ab_0             conda-forge       14kB
#   + tomli                                   2.1.0  pyhff2d567_0             conda-forge       19kB
#   + pygments                               2.18.0  pyhd8ed1ab_0             conda-forge      879kB
#   + mistune                                 3.0.2  pyhd8ed1ab_0             conda-forge       66kB
#   + pandocfilters                           1.5.0  pyhd8ed1ab_0             conda-forge       12kB
#   + entrypoints                               0.4  pyhd8ed1ab_0             conda-forge        9kB
#   + defusedxml                              0.7.1  pyhd8ed1ab_0             conda-forge       24kB
#   + python-fastjsonschema                  2.20.0  pyhd8ed1ab_0             conda-forge      226kB
#   + send2trash                              1.8.3  pyh0d859eb_0             conda-forge       23kB
#   + prometheus_client                      0.21.0  pyhd8ed1ab_0             conda-forge       49kB
#   + traitlets                              5.14.3  pyhd8ed1ab_0             conda-forge      110kB
#   + nest-asyncio                            1.6.0  pyhd8ed1ab_0             conda-forge       12kB
#   + widgetsnbextension                     4.0.13  pyhd8ed1ab_0             conda-forge      899kB
#   + jupyterlab_widgets                     3.0.13  pyhd8ed1ab_0             conda-forge      186kB
#   + fonts-conda-ecosystem                       1  0                        conda-forge        4kB
#   + babel                                  2.16.0  pyhd8ed1ab_0             conda-forge        7MB
#   + jedi                                   0.19.2  pyhff2d567_0             conda-forge      843kB
#   + prompt-toolkit                         3.0.48  pyha770c72_0             conda-forge      270kB
#   + pexpect                                 4.9.0  pyhd8ed1ab_0             conda-forge       54kB
#   + cached-property                         1.5.2  hd8ed1ab_1               conda-forge        4kB
#   + asttokens                               2.4.1  pyhd8ed1ab_0             conda-forge       29kB
#   + python-dateutil                   2.9.0.post0  pyhff2d567_0             conda-forge      222kB
#   + rfc3339-validator                       0.1.4  pyhd8ed1ab_0             conda-forge        8kB
#   + beautifulsoup4                         4.12.3  pyha770c72_0             conda-forge      118kB
#   + tinycss2                                1.4.0  pyhd8ed1ab_0             conda-forge       28kB
#   + bleach                                  6.2.0  pyhd8ed1ab_0             conda-forge      133kB
#   + h2                                      4.1.0  pyhd8ed1ab_0             conda-forge       47kB
#   + importlib_resources                     6.4.5  pyhd8ed1ab_0             conda-forge       33kB
#   + importlib-metadata                      8.5.0  pyha770c72_0             conda-forge       29kB
#   + h11                                    0.14.0  pyhd8ed1ab_0             conda-forge       48kB
#   + typing-extensions                      4.12.2  hd8ed1ab_0               conda-forge       10kB
#   + async-lru                               2.0.4  pyhd8ed1ab_0             conda-forge       15kB
#   + anyio                             4.6.2.post1  pyhd8ed1ab_0             conda-forge      110kB
#   + overrides                               7.7.0  pyhd8ed1ab_0             conda-forge       30kB
#   + jupyterlab_pygments                     0.3.0  pyhd8ed1ab_1             conda-forge       19kB
#   + jupyter_core                            5.7.2  pyh31011fe_1             conda-forge       58kB
#   + comm                                    0.2.2  pyhd8ed1ab_0             conda-forge       12kB
#   + matplotlib-inline                       0.1.7  pyhd8ed1ab_0             conda-forge       15kB
#   + prompt_toolkit                         3.0.48  hd8ed1ab_0               conda-forge        7kB
#   + fqdn                                    1.5.1  pyhd8ed1ab_0             conda-forge       14kB
#   + stack_data                              0.6.2  pyhd8ed1ab_0             conda-forge       26kB
#   + arrow                                   1.3.0  pyhd8ed1ab_0             conda-forge      100kB
#   + httpcore                                1.0.7  pyh29332c3_1             conda-forge       49kB
#   + ipython                                8.29.0  pyh707e725_0             conda-forge      599kB
#   + isoduration                           20.11.0  pyhd8ed1ab_0             conda-forge       17kB
#   + httpx                                  0.27.2  pyhd8ed1ab_0             conda-forge       65kB
#   + ipywidgets                              8.1.5  pyhd8ed1ab_0             conda-forge      113kB
#   + unicodedata2                           15.1.0  py310ha75aee5_1          conda-forge      368kB
#   + pillow                                 11.0.0  py310hfeaa1f3_0          conda-forge       43MB
#   + kiwisolver                              1.4.7  py310h3788b33_0          conda-forge       72kB
#   + argon2-cffi-bindings                   21.2.0  py310ha75aee5_5          conda-forge       34kB
#   + debugpy                                 1.8.9  py310hf71b8c6_0          conda-forge        2MB
#   + rpds-py                                0.21.0  py310h505e2c1_0          conda-forge      334kB
#   + pyyaml                                  6.0.2  py310ha75aee5_1          conda-forge      183kB
#   + markupsafe                              3.0.2  py310h89163eb_0          conda-forge       23kB
#   + pyzmq                                  26.2.0  py310h71f11fc_1          conda-forge      338kB
#   + tornado                                 6.4.1  py310ha75aee5_1          conda-forge      651kB
#   + psutil                                  6.1.0  py310ha75aee5_0          conda-forge      369kB
#   + numpy                                   2.1.3  py310hd6e36ab_0          conda-forge        8MB
#   + cython                                 3.0.11  py310h5b1441d_3          conda-forge        3MB
#   + cairo                                  1.18.0  hbb29018_2               conda-forge      984kB
#   + fonttools                              4.55.0  py310h89163eb_0          conda-forge        2MB
#   + contourpy                               1.3.1  py310h3788b33_0          conda-forge      261kB
#   + scipy                                  1.14.1  py310hfcf56fc_1          conda-forge       17MB
#   + h5py                                   3.12.1  nompi_py310h60e0fe6_102  conda-forge        1MB
#   + harfbuzz                                8.5.0  hfac3d4d_0               conda-forge        2MB
#   + matplotlib-base                         3.9.2  py310h68603db_2          conda-forge        7MB
#   + qt6-main                                6.7.2  h0f8cd61_2               conda-forge       47MB
#   + pyside6                                 6.7.2  py310hfd10a26_4          conda-forge       11MB
#   + matplotlib                              3.9.2  py310hff52083_2          conda-forge       17kB
#   + argon2-cffi                            23.1.0  pyhd8ed1ab_0             conda-forge       19kB
#   + referencing                            0.35.1  pyhd8ed1ab_0             conda-forge       42kB
#   + jinja2                                  3.1.4  pyhd8ed1ab_0             conda-forge      112kB
#   + terminado                              0.18.1  pyh0d859eb_0             conda-forge       22kB
#   + jupyter_client                          7.4.9  pyhd8ed1ab_0             conda-forge       99kB
#   + jsonschema-specifications           2024.10.1  pyhd8ed1ab_0             conda-forge       16kB
#   + jupyter_server_terminals                0.5.3  pyhd8ed1ab_0             conda-forge       20kB
#   + ipykernel                              6.29.5  pyh3099207_0             conda-forge      119kB
#   + jsonschema                             4.23.0  pyhd8ed1ab_0             conda-forge       74kB
#   + jupyter_console                         6.6.3  pyhd8ed1ab_0             conda-forge       26kB
#   + jsonschema-with-format-nongpl          4.23.0  hd8ed1ab_0               conda-forge        7kB
#   + nbformat                               5.10.4  pyhd8ed1ab_0             conda-forge      101kB
#   + jupyter_events                         0.10.0  pyhd8ed1ab_0             conda-forge       21kB
#   + nbclient                               0.10.0  pyhd8ed1ab_0             conda-forge       28kB
#   + nbconvert-core                         7.16.4  pyhd8ed1ab_1             conda-forge      190kB
#   + jupyter_server                         2.14.2  pyhd8ed1ab_0             conda-forge      324kB
#   + jupyterlab_server                      2.27.3  pyhd8ed1ab_0             conda-forge       49kB
#   + jupyter-lsp                             2.2.5  pyhd8ed1ab_0             conda-forge       56kB
#   + notebook-shim                           0.2.4  pyhd8ed1ab_0             conda-forge       17kB
#   + nbclassic                               1.1.0  pyhd8ed1ab_0             conda-forge        5MB
#   + jupyterlab                              4.3.1  pyhff2d567_0             conda-forge        7MB
#   + notebook                                6.5.7  pyha770c72_0             conda-forge      309kB
#   + jupyter                                 1.1.1  pyhd8ed1ab_0             conda-forge        9kB
#
#   Reinstall:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   o tk                                     8.6.13  noxft_h4845f30_101       conda-forge     Cached
#   o libnghttp2                             1.58.0  h47da74e_1               conda-forge     Cached
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - libgomp                                13.2.0  h807b86a_3               conda-forge     Cached
#   + libgomp                                14.2.0  h77fa898_1               conda-forge      461kB
#   - libgcc-ng                              13.2.0  h807b86a_3               conda-forge     Cached
#   + libgcc-ng                              14.2.0  h69a702a_1               conda-forge       54kB
#   - ncurses                                   6.4  h59595ed_2               conda-forge     Cached
#   + ncurses                                   6.5  he02047a_1               conda-forge      889kB
#   - libzlib                                1.2.13  hd590300_5               conda-forge     Cached
#   + libzlib                                 1.3.1  hb9d3cd8_2               conda-forge       61kB
#   - openssl                                 3.2.0  hd590300_1               conda-forge     Cached
#   + openssl                                 3.4.0  hb9d3cd8_0               conda-forge        3MB
#   - libxml2                                2.12.3  h232c23b_0               conda-forge     Cached
#   + libxml2                                2.12.7  h4c95cb1_3               conda-forge      706kB
#   - libsqlite                              3.44.2  h2797004_0               conda-forge     Cached
#   + libsqlite                              3.47.0  hadc24fc_1               conda-forge      875kB
#   - libsolv                                0.7.27  hfc55251_0               conda-forge     Cached
#   + libsolv                                0.7.30  h3509ff9_0               conda-forge      471kB
#   - zstd                                    1.5.5  hfc55251_0               conda-forge     Cached
#   + zstd                                    1.5.6  ha6fb4c9_0               conda-forge      555kB
#   - libssh2                                1.11.0  h0841786_0               conda-forge     Cached
#   + libssh2                                1.11.1  hf672d98_0               conda-forge      304kB
#   - python                                3.10.13  hd12c33a_0_cpython       conda-forge     Cached
#   + python                                3.10.15  h4a871b0_2_cpython       conda-forge       25MB
#   - libarchive                              3.7.2  h2aa1ff5_1               conda-forge     Cached
#   + libarchive                              3.7.4  hfca40fe_0               conda-forge      872kB
#   - libcurl                                 8.5.0  hca28451_0               conda-forge     Cached
#   + libcurl                                 8.8.0  hca28451_0               conda-forge      406kB
#   - pip                                    23.3.2  pyhd8ed1ab_0             conda-forge     Cached
#   + pip                                    24.3.1  pyh8b19718_0             conda-forge        1MB
# [+] 3.3s
# Downloading  (4)   75%
# Extracting  (132)  ⣾  [+] 3.4s
# Downloading  (5)   77%
# Extracting  (131)  ⣾  mistune                                             66.0kB @  19.2kB/s  0.1s
# [+] 3.5s
# Downloading  (4)   79%
# Extracting  (129)  ⣾  python-fastjsonschema                              226.2kB @  63.0kB/s  0.1s
# [+] 3.6s
# Downloading  (4)   81%
# Extracting  (129)  ⣾  libclang13                                          11.8MB @   3.2MB/s  0.6s
# jedi                                               842.9kB @ 228.4kB/s  0.1s
# prompt-toolkit                                     270.3kB @  73.2kB/s  0.1s
# [+] 3.7s
# Downloading  (5)   84%
# Extracting  (130)  ⣾  async-lru                                           15.3kB @   4.1kB/s  0.1s
# anyio                                              109.9kB @  29.3kB/s  0.1s
# [+] 3.8s
# Downloading  (5)   88%
# Extracting  (134)  ⣾  libclang-cpp18.1                                    19.2MB @   5.0MB/s  0.8s
# argon2-cffi-bindings                                34.4kB @   9.0kB/s  0.1s
# [+] 3.9s
# Downloading  (5)   90%
# Extracting  (135)  ⣾  debugpy                                              2.2MB @ 559.2kB/s  0.2s
# contourpy                                          261.0kB @  66.8kB/s  0.1s
# h5py                                                 1.3MB @ 331.0kB/s  0.1s
# jupyterlab_server                                   49.4kB @  12.4kB/s  0.1s
# jupyter-lsp                                         55.5kB @  14.0kB/s  0.1s
# libdeflate                                          72.2kB @  18.1kB/s  0.1s
# [+] 4.0s
# Downloading  (5)   91%
# Extracting  (141)  ⣾  xcb-util-wm                                         51.7kB @  12.8kB/s  0.1s
# xcb-util-renderutil                                 17.0kB @   4.2kB/s  0.1s
# [+] 4.1s
# Downloading  (5)   93%
# Extracting  (141)  ⣾  openssl                                              2.9MB @ 720.5kB/s  0.1s
# libxkbcommon                                       593.3kB @ 144.4kB/s  0.1s
# brotli                                              19.4kB @   4.7kB/s  0.1s
# [+] 4.2s
# Downloading  (5)   95%
# Extracting  (144)  ⣾  [+] 4.3s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  [+] 4.4s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  [+] 4.5s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  [+] 4.6s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  [+] 4.7s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  [+] 4.8s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  [+] 4.9s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  [+] 5.0s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  [+] 5.1s
# Downloading  (5)   95%
# Extracting  (143)  ⣾  hpack                                               25.3kB @   5.0kB/s  1.0s
# zipp                                                21.7kB @   4.2kB/s  1.0s
# pandocfilters                                       11.6kB @   2.3kB/s  1.0s
# [+] 5.2s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 5.3s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 5.4s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 5.5s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 5.6s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 5.7s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 5.8s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 5.9s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 6.0s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 6.1s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 6.2s
# Downloading  (5)   95%
# Extracting  (146)  ⣾  [+] 6.3s
# Downloading  (5)   96%
# Extracting  (146)  ⣾  pillow                                              42.6MB @   8.3MB/s  3.7s
# beautifulsoup4                                     118.2kB @  18.7kB/s  1.2s
# overrides                                           30.2kB @   4.8kB/s  1.2s
# comm                                                12.1kB @   1.9kB/s  1.2s
# [+] 6.4s
# Downloading  (5)   96%
# Extracting  (150)  ⣾  [+] 6.5s
# Downloading  (5)   96%
# Extracting  (150)  ⣾  [+] 6.6s
# Downloading  (5)   96%
# Extracting  (150)  ⣾  [+] 6.7s
# Downloading  (5)   96%
# Extracting  (150)  ⣾  [+] 6.8s
# Downloading  (5)   96%
# Extracting  (150)  ⣾  [+] 6.9s
# Downloading  (5)   96%
# Extracting  (150)  ⣾  [+] 7.0s
# Downloading  (5)   96%
# Extracting  (150)  ⣾  [+] 7.1s
# Downloading  (5)   96%
# Extracting  (150)  ⣾  jsonschema-specifications                           16.2kB @   2.3kB/s  0.8s
# jupyter_server_terminals                            19.8kB @   2.8kB/s  0.8s
# jupyter_events                                      21.5kB @   3.0kB/s  0.8s
# xorg-libxdmcp                                       19.9kB @   2.8kB/s  0.8s
# qt6-main                                            47.0MB @   6.5MB/s  4.5s
# [+] 7.2s
# Downloading  (5)   96%
# Extracting  (155)  ⣾  fontconfig                                         265.6kB @  36.8kB/s  0.0s
# xcb-util-cursor                                     20.3kB @   2.8kB/s  0.0s
# rfc3339-validator                                    8.1kB @   1.1kB/s  0.0s
# freetype                                           635.0kB @  87.5kB/s  0.1s
# mysql-libs                                           1.5MB @ 211.1kB/s  0.1s
# libopengl                                           50.8kB @   7.0kB/s  0.1s
# libwebp-base                                       439.0kB @  60.5kB/s  0.1s
# xorg-libxrender                                     37.8kB @   5.2kB/s  0.0s
# entrypoints                                          9.2kB @   1.3kB/s  0.0s
# jupyterlab_widgets                                 186.0kB @  25.5kB/s  0.0s
# hyperframe                                          14.6kB @   2.0kB/s  0.0s
# webencodings                                        15.6kB @   2.1kB/s  0.0s
# [+] 7.3s
# Downloading  (5)   97%
# Extracting  (162)  ⣾  widgetsnbextension                                 898.7kB @ 122.8kB/s  0.1s
# munkres                                             12.5kB @   1.7kB/s  0.0s
# matplotlib-inline                                   14.6kB @   2.0kB/s  0.0s
# ipywidgets                                         113.5kB @  15.5kB/s  0.0s
# libgfortran-ng                                      54.1kB @   7.4kB/s  0.0s
# pcre2                                              950.8kB @ 129.2kB/s  0.1s
# [+] 7.4s
# Downloading  (5)   98%
# Extracting  (172)  ⣾  libbrotlicommon                                     69.4kB @   9.4kB/s  0.0s
# pixman                                             386.8kB @  52.2kB/s  0.0s
# unicodedata2                                       368.1kB @  49.7kB/s  0.1s
# zstandard                                          408.3kB @  55.1kB/s  0.1s
# referencing                                         42.2kB @   5.7kB/s  0.0s
# [+] 7.5s
# Downloading  (1)  100%
# Extracting  (177)  ⣾  python-dateutil                                    221.9kB @  29.7kB/s  0.1s
# cached_property                                     11.1kB @   1.5kB/s  0.1s
# numpy                                                7.9MB @   1.0MB/s  0.2s
# [+] 7.6s
# Downloading       100%
# Extracting  (179)  ⣾  [+] 7.7s
# Downloading       100%
# Extracting  (179)  ⣾  [+] 7.8s
# Downloading       100%
# Extracting  (178)  ⣾  [+] 7.9s
# Downloading       100%
# Extracting  (178)  ⣾  [+] 8.0s
# Downloading       100%
# Extracting  (177)  ⣾  [+] 8.1s
# Downloading       100%
# Extracting  (177)  ⣾  [+] 8.2s
# Downloading       100%
# Extracting  (177)  ⣾  [+] 8.3s
# Downloading       100%
# Extracting  (177)  ⣾  [+] 8.4s
# Downloading       100%
# Extracting  (177)  ⣾  [+] 8.5s
# Downloading       100%
# Extracting  (177)  ⣾  [+] 8.6s
# Downloading       100%
# Extracting  (177)  ⣾  [+] 8.7s
# Downloading       100%
# Extracting  (176)  ⣾  [+] 8.8s
# Downloading       100%
# Extracting  (176)  ⣾  [+] 8.9s
# Downloading       100%
# Extracting  (175)  ⣾  [+] 9.0s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 9.1s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 9.2s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 9.3s
# Downloading       100%
# Extracting  (174)  ⣾  [+] 9.4s
# Downloading       100%
# Extracting  (173)  ⣾  [+] 9.5s
# Downloading       100%
# Extracting  (173)  ⣾  [+] 9.6s
# Downloading       100%
# Extracting  (171)  ⣾  [+] 9.7s
# Downloading       100%
# Extracting  (171)  ⣾  [+] 9.8s
# Downloading       100%
# Extracting  (169)  ⣾  [+] 9.9s
# Downloading       100%
# Extracting  (167)  ⣾  [+] 10.0s
# ...
# Installing jupyter-bundlerextension script to /usr/local/bin
# Installing jupyter-nbextension script to /usr/local/bin
# Installing jupyter-notebook script to /usr/local/bin
# Installing jupyter-serverextension script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for traitlets==5.14.3
# Best match: traitlets 5.14.3
# Adding traitlets 5.14.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for tornado==6.4.1
# Best match: tornado 6.4.1
# Adding tornado 6.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for tomli==2.1.0
# Best match: tomli 2.1.0
# Adding tomli 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for notebook-shim==0.2.4
# Best match: notebook-shim 0.2.4
# Adding notebook-shim 0.2.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyterlab-server==2.27.3
# Best match: jupyterlab-server 2.27.3
# Adding jupyterlab-server 2.27.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyter-server==2.14.2
# Best match: jupyter-server 2.14.2
# Adding jupyter-server 2.14.2 to easy-install.pth file
# Installing jupyter-server script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyter-lsp==2.2.5
# Best match: jupyter-lsp 2.2.5
# Adding jupyter-lsp 2.2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyter-core==5.7.2
# Best match: jupyter-core 5.7.2
# Adding jupyter-core 5.7.2 to easy-install.pth file
# Installing jupyter script to /usr/local/bin
# Installing jupyter-migrate script to /usr/local/bin
# Installing jupyter-troubleshoot script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jinja2==3.1.4
# Best match: jinja2 3.1.4
# Adding jinja2 3.1.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for httpx==0.27.2
# Best match: httpx 0.27.2
# Adding httpx 0.27.2 to easy-install.pth file
# Installing httpx script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for async-lru==2.0.4
# Best match: async-lru 2.0.4
# Adding async-lru 2.0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyterlab-widgets==3.0.13
# Best match: jupyterlab-widgets 3.0.13
# Adding jupyterlab-widgets 3.0.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for widgetsnbextension==4.0.13
# Best match: widgetsnbextension 4.0.13
# Adding widgetsnbextension 4.0.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for ipython==8.29.0
# Best match: ipython 8.29.0
# Adding ipython 8.29.0 to easy-install.pth file
# Installing ipython script to /usr/local/bin
# Installing ipython3 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for comm==0.2.2
# Best match: comm 0.2.2
# Adding comm 0.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for pyzmq==26.2.0
# Best match: pyzmq 26.2.0
# Adding pyzmq 26.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for nest-asyncio==1.6.0
# Best match: nest-asyncio 1.6.0
# Adding nest-asyncio 1.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for matplotlib-inline==0.1.7
# Best match: matplotlib-inline 0.1.7
# Adding matplotlib-inline 0.1.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyter-client==7.4.9
# Best match: jupyter-client 7.4.9
# Adding jupyter-client 7.4.9 to easy-install.pth file
# Installing jupyter-kernel script to /usr/local/bin
# Installing jupyter-kernelspec script to /usr/local/bin
# Installing jupyter-run script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for debugpy==1.8.9
# Best match: debugpy 1.8.9
# Adding debugpy 1.8.9 to easy-install.pth file
# Installing debugpy script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for tinycss2==1.4.0
# Best match: tinycss2 1.4.0
# Adding tinycss2 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for pygments==2.18.0
# Best match: pygments 2.18.0
# Adding pygments 2.18.0 to easy-install.pth file
# Installing pygmentize script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for pandocfilters==1.5.0
# Best match: pandocfilters 1.5.0
# Adding pandocfilters 1.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for nbformat==5.10.4
# Best match: nbformat 5.10.4
# Adding nbformat 5.10.4 to easy-install.pth file
# Installing jupyter-trust script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for nbclient==0.10.0
# Best match: nbclient 0.10.0
# Adding nbclient 0.10.0 to easy-install.pth file
# Installing jupyter-execute script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for mistune==3.0.2
# Best match: mistune 3.0.2
# Adding mistune 3.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for MarkupSafe==3.0.2
# Best match: MarkupSafe 3.0.2
# Adding MarkupSafe 3.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyterlab-pygments==0.3.0
# Best match: jupyterlab-pygments 0.3.0
# Adding jupyterlab-pygments 0.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for defusedxml==0.7.1
# Best match: defusedxml 0.7.1
# Adding defusedxml 0.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for bleach==6.2.0
# Best match: bleach 6.2.0
# Adding bleach 6.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for beautifulsoup4==4.12.3
# Best match: beautifulsoup4 4.12.3
# Adding beautifulsoup4 4.12.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for prompt-toolkit==3.0.48
# Best match: prompt-toolkit 3.0.48
# Adding prompt-toolkit 3.0.48 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for nbclassic==1.1.0
# Best match: nbclassic 1.1.0
# Adding nbclassic 1.1.0 to easy-install.pth file
# Installing jupyter-nbclassic script to /usr/local/bin
# Installing jupyter-nbclassic-bundlerextension script to /usr/local/bin
# Installing jupyter-nbclassic-extension script to /usr/local/bin
# Installing jupyter-nbclassic-serverextension script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for prometheus-client==0.21.0
# Best match: prometheus-client 0.21.0
# Adding prometheus-client 0.21.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for terminado==0.18.1
# Best match: terminado 0.18.1
# Adding terminado 0.18.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for Send2Trash==1.8.3
# Best match: Send2Trash 1.8.3
# Adding Send2Trash 1.8.3 to easy-install.pth file
# Installing send2trash script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for ipython-genutils==0.2.0
# Best match: ipython-genutils 0.2.0
# Adding ipython-genutils 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for argon2-cffi==23.1.0
# Best match: argon2-cffi 23.1.0
# Adding argon2-cffi 23.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for requests==2.31.0
# Best match: requests 2.31.0
# Adding requests 2.31.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jsonschema==4.23.0
# Best match: jsonschema 4.23.0
# Adding jsonschema 4.23.0 to easy-install.pth file
# Installing jsonschema script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for json5==0.9.28
# Best match: json5 0.9.28
# Adding json5 0.9.28 to easy-install.pth file
# Installing pyjson5 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for babel==2.16.0
# Best match: babel 2.16.0
# Adding babel 2.16.0 to easy-install.pth file
# Installing pybabel script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for websocket-client==1.8.0
# Best match: websocket-client 1.8.0
# Adding websocket-client 1.8.0 to easy-install.pth file
# Installing wsdump script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for overrides==7.7.0
# Best match: overrides 7.7.0
# Adding overrides 7.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyter-server-terminals==0.5.3
# Best match: jupyter-server-terminals 0.5.3
# Adding jupyter-server-terminals 0.5.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jupyter-events==0.10.0
# Best match: jupyter-events 0.10.0
# Adding jupyter-events 0.10.0 to easy-install.pth file
# Installing jupyter-events script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for anyio==4.6.2.post1
# Best match: anyio 4.6.2.post1
# Adding anyio 4.6.2.post1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for platformdirs==4.1.0
# Best match: platformdirs 4.1.0
# Adding platformdirs 4.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for sniffio==1.3.1
# Best match: sniffio 1.3.1
# Adding sniffio 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for idna==3.6
# Best match: idna 3.6
# Adding idna 3.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for httpcore==1.0.7
# Best match: httpcore 1.0.7
# Adding httpcore 1.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for certifi==2023.11.17
# Best match: certifi 2023.11.17
# Adding certifi 2023.11.17 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for typing-extensions==4.12.2
# Best match: typing-extensions 4.12.2
# Adding typing-extensions 4.12.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for pexpect==4.9.0
# Best match: pexpect 4.9.0
# Adding pexpect 4.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for exceptiongroup==1.2.2
# Best match: exceptiongroup 1.2.2
# Adding exceptiongroup 1.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for stack-data==0.6.2
# Best match: stack-data 0.6.2
# Adding stack-data 0.6.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jedi==0.19.2
# Best match: jedi 0.19.2
# Adding jedi 0.19.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for decorator==5.1.1
# Best match: decorator 5.1.1
# Adding decorator 5.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for entrypoints==0.4
# Best match: entrypoints 0.4
# Adding entrypoints 0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for webencodings==0.5.1
# Best match: webencodings 0.5.1
# Adding webencodings 0.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for fastjsonschema==2.20.0
# Best match: fastjsonschema 2.20.0
# Adding fastjsonschema 2.20.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for soupsieve==2.5
# Best match: soupsieve 2.5
# Adding soupsieve 2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for wcwidth==0.2.13
# Best match: wcwidth 0.2.13
# Adding wcwidth 0.2.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for ptyprocess==0.7.0
# Best match: ptyprocess 0.7.0
# Adding ptyprocess 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for argon2-cffi-bindings==21.2.0
# Best match: argon2-cffi-bindings 21.2.0
# Adding argon2-cffi-bindings 21.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for urllib3==2.1.0
# Best match: urllib3 2.1.0
# Adding urllib3 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for charset-normalizer==3.3.2
# Best match: charset-normalizer 3.3.2
# Adding charset-normalizer 3.3.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for rpds-py==0.21.0
# Best match: rpds-py 0.21.0
# Adding rpds-py 0.21.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for referencing==0.35.1
# Best match: referencing 0.35.1
# Adding referencing 0.35.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jsonschema-specifications==2024.10.1
# Best match: jsonschema-specifications 2024.10.1
# Adding jsonschema-specifications 2024.10.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for attrs==24.2.0
# Best match: attrs 24.2.0
# Adding attrs 24.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for rfc3986-validator==0.1.1
# Best match: rfc3986-validator 0.1.1
# Adding rfc3986-validator 0.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for rfc3339-validator==0.1.4
# Best match: rfc3339-validator 0.1.4
# Adding rfc3339-validator 0.1.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for PyYAML==6.0.2
# Best match: PyYAML 6.0.2
# Adding PyYAML 6.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for python-json-logger==2.0.7
# Best match: python-json-logger 2.0.7
# Adding python-json-logger 2.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for h11==0.14.0
# Best match: h11 0.14.0
# Adding h11 0.14.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for pure-eval==0.2.3
# Best match: pure-eval 0.2.3
# Adding pure-eval 0.2.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for asttokens==2.4.1
# Best match: asttokens 2.4.1
# Adding asttokens 2.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for executing==2.1.0
# Best match: executing 2.1.0
# Adding executing 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for parso==0.8.4
# Best match: parso 0.8.4
# Adding parso 0.8.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for cffi==1.16.0
# Best match: cffi 1.16.0
# Adding cffi 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for webcolors==24.8.0
# Best match: webcolors 24.8.0
# Adding webcolors 24.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for uri-template==1.3.0
# Best match: uri-template 1.3.0
# Adding uri-template 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for jsonpointer==2.4
# Best match: jsonpointer 2.4
# Adding jsonpointer 2.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for isoduration==20.11.0
# Best match: isoduration 20.11.0
# Adding isoduration 20.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for fqdn==1.5.1
# Best match: fqdn 1.5.1
# Adding fqdn 1.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for pycparser==2.21
# Best match: pycparser 2.21
# Adding pycparser 2.21 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for arrow==1.3.0
# Best match: arrow 1.3.0
# Adding arrow 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Searching for types-python-dateutil==2.9.0.20241003
# Best match: types-python-dateutil 2.9.0.20241003
# Adding types-python-dateutil 2.9.0.20241003 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/site-packages
# Finished processing dependencies for gprMax==3.1.7

# %%
# !python -m gprMax user_models/cylinder_Ascan_2D.in  -n 2
# Out:
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method ===
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.7 (Big Smoke)
#
#  Copyright (C) 2015-2023: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the terms of the GNU
#   General Public License as published by the Free Software Foundation, either version 3 of the
#   License, or (at your option) any later version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even
#   the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the GNU General
#   Public License for more details.
#  You should have received a copy of the GNU General Public License along with gprMax.  If not, see
#   www.gnu.org/licenses.
#
# Host: 90f8c9c85912 | Google Google Compute Engine | 1 x Intel(R) Xeon(R) CPU @ 2.20GHz (1 cores, 2 cores with Hyper-Threading) | 12.7GiB RAM | Linux-6.1.85+-x86_64-with-glibc2.35
#
# --- Model 1/2, input file: user_models/cylinder_Ascan_2D.in ---------------------------------------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 1, e0: 8.8541878128e-12, inputfile: /content/gprMax/user_models/cylinder_Ascan_2D.in, m0: 1.25663706212e-06, number_model_runs: 2, z0: 376.73031366686166}
#
# Model title: A-scan from a metal cylinder buried in a dielectric half-space
# Number of CPU (OpenMP) threads: 1
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 0.24 x 0.21 x 0.002m (120 x 105 x 1 = 12600 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 3e-09 secs (637 iterations)
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# Hertzian dipole with polarity z at 0.1m, 0.17m, 0m, using waveform my_ricker created.
# Receiver at 0.14m, 0.17m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.24m, 0.21m, 0.002m, discretisation 0.002m, 0.002m, 0.002m, with filename base cylinder_half_space created.
#
# Memory (RAM) required: ~51.5MB
#
# Box from 0m, 0m, 0m, to 0.24m, 0.17m, 0.002m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.12m, 0.08m, 0m and 0.12m, 0.08m, 0.002m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|██████████████████████████| 2/2 [00:00<00:00, 1228.20cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 2653.78it/s]
#
# Building main grid: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 497.90it/s]
#
# Materials:
#     |                                             |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                                        | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+---------------------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                                         | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                                  | builtin             | 1     | 0     | 1    | 0       | True
#   2 | half_space                                  |                     | 6     | 0     | 1    | 0       | True
#   3 | free_space+free_space+half_space+half_space | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.42% in material 'half_space' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.32623e+09Hz
#
# Writing geometry view file 1/1, cylinder_half_space1.vti: 100%|█| 75.6k/75.6k [00:00<00:00, 103Mbyt
#
# Output file: /content/gprMax/user_models/cylinder_Ascan_2D1.out
#
# Running simulation, model 1/2: 100%|███████████████████████████| 637/637 [00:00<00:00, 1622.54it/s]
# Memory (RAM) used: ~87.2MB
# Solving time [HH:MM:SS]: 0:00:00.393140
#
# --- Model 2/2, input file: user_models/cylinder_Ascan_2D.in ---------------------------------------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 2, e0: 8.8541878128e-12, inputfile: /content/gprMax/user_models/cylinder_Ascan_2D.in, m0: 1.25663706212e-06, number_model_runs: 2, z0: 376.73031366686166}
#
# Model title: A-scan from a metal cylinder buried in a dielectric half-space
# Number of CPU (OpenMP) threads: 1
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 0.24 x 0.21 x 0.002m (120 x 105 x 1 = 12600 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 3e-09 secs (637 iterations)
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# Hertzian dipole with polarity z at 0.1m, 0.17m, 0m, using waveform my_ricker created.
# Receiver at 0.14m, 0.17m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.24m, 0.21m, 0.002m, discretisation 0.002m, 0.002m, 0.002m, with filename base cylinder_half_space created.
#
# Memory (RAM) required: ~51.5MB
#
# Box from 0m, 0m, 0m, to 0.24m, 0.17m, 0.002m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.12m, 0.08m, 0m and 0.12m, 0.08m, 0.002m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|███████████████████████████| 2/2 [00:00<00:00, 758.40cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 1703.27it/s]
#
# Building main grid: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 385.33it/s]
#
# Materials:
#     |                                             |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                                        | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+---------------------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                                         | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                                  | builtin             | 1     | 0     | 1    | 0       | True
#   2 | half_space                                  |                     | 6     | 0     | 1    | 0       | True
#   3 | free_space+free_space+half_space+half_space | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.42% in material 'half_space' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.32623e+09Hz
#
# Writing geometry view file 1/1, cylinder_half_space2.vti: 100%|█| 75.6k/75.6k [00:00<00:00, 104Mbyt
#
# Output file: /content/gprMax/user_models/cylinder_Ascan_2D2.out
#
# Running simulation, model 2/2: 100%|███████████████████████████| 637/637 [00:00<00:00, 1108.85it/s]
# Memory (RAM) used: ~87.1MB
# Solving time [HH:MM:SS]: 0:00:00.574929
#
# === Simulation completed in [HH:MM:SS]: 0:00:01.187212 ============================================

# %%
# !echo "Sample text Пример текста"
# Out:
# Sample text Пример текста

# %%
# !python -m gprMax user_models/cylinder_Ascan_2D.in  -n 2 >> English.txt

# %%
# !cat English.txt
# Out:
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.6 (Big Smoke)
#
#  Copyright (C) 2015-2022: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the
#   terms of the GNU General Public License as published by the Free Software
#   Foundation, either version 3 of the License, or (at your option) any later
#   version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY
#   WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR
#   A PARTICULAR PURPOSE.  See the GNU General Public License for more details.
#  You should have received a copy of the GNU General Public License along with
#   gprMax.  If not, see www.gnu.org/licenses.
#
# Host: af2a7564b4de | Google Google Compute Engine | 1 x Intel(R) Xeon(R) CPU @ 2.20GHz (1 cores, 2 cores with Hyper-Threading) | 12.7GiB RAM | Linux-5.10.133+-x86_64-with-debian-buster-sid
#
# --- Model 1/2, input file: user_models/cylinder_Ascan_2D.in -------------------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 1, e0: 8.8541878128e-12, inputfile: /content/gprMax/user_models/cylinder_Ascan_2D.in, m0: 1.25663706212e-06, number_model_runs: 2, z0: 376.73031366686166}
#
# Model title: A-scan from a metal cylinder buried in a dielectric half-space
# Number of CPU (OpenMP) threads: 1
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 0.24 x 0.21 x 0.002m (120 x 105 x 1 = 12600 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 3e-09 secs (637 iterations)
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# Hertzian dipole with polarity z at 0.1m, 0.17m, 0m, using waveform my_ricker created.
# Receiver at 0.14m, 0.17m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.24m, 0.21m, 0.002m, discretisation 0.002m, 0.002m, 0.002m, with filename base cylinder_half_space created.
#
# Memory (RAM) required: ~51.5MB
#
# Box from 0m, 0m, 0m, to 0.24m, 0.17m, 0.002m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.12m, 0.08m, 0m and 0.12m, 0.08m, 0.002m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|███████| 2/2 [00:00<00:00, 941.48cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|█████████████████| 4/4 [00:00<00:00, 1060.17it/s]
#
# Building main grid: 100%|███████████████████████| 2/2 [00:00<00:00, 594.98it/s]
#
# Materials:
#     |                                             |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                                        | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+---------------------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                                         | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                                  | builtin             | 1     | 0     | 1    | 0       | True
#   2 | half_space                                  |                     | 6     | 0     | 1    | 0       | True
#   3 | free_space+free_space+half_space+half_space | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.42% in material 'half_space' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.32623e+09Hz
#
# Writing geometry view file 1/1, cylinder_half_space1.vti: 100%|█| 75.6k/75.6k [
#
# Output file: /content/gprMax/user_models/cylinder_Ascan_2D1.out
#
# Running simulation, model 1/2: 100%|███████| 637/637 [00:00<00:00, 1732.38it/s]
# Memory (RAM) used: ~69.9MB
# Solving time [HH:MM:SS]: 0:00:00.368434
#
# --- Model 2/2, input file: user_models/cylinder_Ascan_2D.in -------------------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 2, e0: 8.8541878128e-12, inputfile: /content/gprMax/user_models/cylinder_Ascan_2D.in, m0: 1.25663706212e-06, number_model_runs: 2, z0: 376.73031366686166}
#
# Model title: A-scan from a metal cylinder buried in a dielectric half-space
# Number of CPU (OpenMP) threads: 1
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 0.24 x 0.21 x 0.002m (120 x 105 x 1 = 12600 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 3e-09 secs (637 iterations)
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# Hertzian dipole with polarity z at 0.1m, 0.17m, 0m, using waveform my_ricker created.
# Receiver at 0.14m, 0.17m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.24m, 0.21m, 0.002m, discretisation 0.002m, 0.002m, 0.002m, with filename base cylinder_half_space created.
#
# Memory (RAM) required: ~51.5MB
#
# Box from 0m, 0m, 0m, to 0.24m, 0.17m, 0.002m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.12m, 0.08m, 0m and 0.12m, 0.08m, 0.002m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|██████| 2/2 [00:00<00:00, 1006.19cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|█████████████████| 4/4 [00:00<00:00, 1091.41it/s]
#
# Building main grid: 100%|███████████████████████| 2/2 [00:00<00:00, 602.37it/s]
#
# Materials:
#     |                                             |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                                        | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+---------------------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                                         | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                                  | builtin             | 1     | 0     | 1    | 0       | True
#   2 | half_space                                  |                     | 6     | 0     | 1    | 0       | True
#   3 | free_space+free_space+half_space+half_space | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.42% in material 'half_space' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.32623e+09Hz
#
# Writing geometry view file 1/1, cylinder_half_space2.vti: 100%|█| 75.6k/75.6k [
#
# Output file: /content/gprMax/user_models/cylinder_Ascan_2D2.out
#
# Running simulation, model 2/2: 100%|███████| 637/637 [00:00<00:00, 1718.76it/s]
# Memory (RAM) used: ~70MB
# Solving time [HH:MM:SS]: 0:00:00.371335
#
# === Simulation completed in [HH:MM:SS]: 0:00:01.047025 ========================

# %%
# !sh myscript.sh
# Out:
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method ===
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.6 (Big Smoke)
#
#  Copyright (C) 2015-2022: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the terms of the GNU
#   General Public License as published by the Free Software Foundation, either version 3 of the
#   License, or (at your option) any later version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even
#   the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the GNU General
#   Public License for more details.
#  You should have received a copy of the GNU General Public License along with gprMax.  If not, see
#   www.gnu.org/licenses.
#
# Host: af2a7564b4de | Google Google Compute Engine | 1 x Intel(R) Xeon(R) CPU @ 2.20GHz (1 cores, 2 cores with Hyper-Threading) | 12.7GiB RAM | Linux-5.10.133+-x86_64-with-debian-buster-sid
#
# --- Model 1/2, input file: user_models/cylinder_Ascan_2D.in ---------------------------------------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 1, e0: 8.8541878128e-12, inputfile: /content/gprMax/user_models/cylinder_Ascan_2D.in, m0: 1.25663706212e-06, number_model_runs: 2, z0: 376.73031366686166}
#
# Model title: A-scan from a metal cylinder buried in a dielectric half-space
# Number of CPU (OpenMP) threads: 1
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 0.24 x 0.21 x 0.002m (120 x 105 x 1 = 12600 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 3e-09 secs (637 iterations)
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# Hertzian dipole with polarity z at 0.1m, 0.17m, 0m, using waveform my_ricker created.
# Receiver at 0.14m, 0.17m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.24m, 0.21m, 0.002m, discretisation 0.002m, 0.002m, 0.002m, with filename base cylinder_half_space created.
#
# Memory (RAM) required: ~51.5MB
#
# Box from 0m, 0m, 0m, to 0.24m, 0.17m, 0.002m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.12m, 0.08m, 0m and 0.12m, 0.08m, 0.002m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|██████████████████████████| 2/2 [00:00<00:00, 1193.09cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████████████████████████| 4/4 [00:00<00:00, 990.27it/s]
#
# Building main grid: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 628.03it/s]
#
# Materials:
#     |                                             |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                                        | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+---------------------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                                         | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                                  | builtin             | 1     | 0     | 1    | 0       | True
#   2 | half_space                                  |                     | 6     | 0     | 1    | 0       | True
#   3 | free_space+free_space+half_space+half_space | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.42% in material 'half_space' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.32623e+09Hz
#
# Writing geometry view file 1/1, cylinder_half_space1.vti: 100%|█| 75.6k/75.6k [00:00<00:00, 77.0Mby
#
# Output file: /content/gprMax/user_models/cylinder_Ascan_2D1.out
#
# Running simulation, model 1/2: 100%|███████████████████████████| 637/637 [00:00<00:00, 1660.16it/s]
# Memory (RAM) used: ~69.6MB
# Solving time [HH:MM:SS]: 0:00:00.384289
#
# --- Model 2/2, input file: user_models/cylinder_Ascan_2D.in ---------------------------------------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 2, e0: 8.8541878128e-12, inputfile: /content/gprMax/user_models/cylinder_Ascan_2D.in, m0: 1.25663706212e-06, number_model_runs: 2, z0: 376.73031366686166}
#
# Model title: A-scan from a metal cylinder buried in a dielectric half-space
# Number of CPU (OpenMP) threads: 1
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 0.24 x 0.21 x 0.002m (120 x 105 x 1 = 12600 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 3e-09 secs (637 iterations)
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# Hertzian dipole with polarity z at 0.1m, 0.17m, 0m, using waveform my_ricker created.
# Receiver at 0.14m, 0.17m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material half_space with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Geometry view from 0m, 0m, 0m, to 0.24m, 0.21m, 0.002m, discretisation 0.002m, 0.002m, 0.002m, with filename base cylinder_half_space created.
#
# Memory (RAM) required: ~51.5MB
#
# Box from 0m, 0m, 0m, to 0.24m, 0.17m, 0.002m of material(s) half_space created, dielectric smoothing is on.
# Cylinder with face centres 0.12m, 0.08m, 0m and 0.12m, 0.08m, 0.002m, with radius 0.01m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|██████████████████████████| 2/2 [00:00<00:00, 1326.05cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 1006.98it/s]
#
# Building main grid: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00, 601.46it/s]
#
# Materials:
#     |                                             |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                                        | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+---------------------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                                         | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                                  | builtin             | 1     | 0     | 1    | 0       | True
#   2 | half_space                                  |                     | 6     | 0     | 1    | 0       | True
#   3 | free_space+free_space+half_space+half_space | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.42% in material 'half_space' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.32623e+09Hz
#
# Writing geometry view file 1/1, cylinder_half_space2.vti: 100%|█| 75.6k/75.6k [00:00<00:00, 77.7Mby
#
# Output file: /content/gprMax/user_models/cylinder_Ascan_2D2.out
#
# Running simulation, model 2/2: 100%|███████████████████████████| 637/637 [00:00<00:00, 1692.36it/s]
# Memory (RAM) used: ~69.6MB
# Solving time [HH:MM:SS]: 0:00:00.376953
#
# === Simulation completed in [HH:MM:SS]: 0:00:01.050074 ============================================
